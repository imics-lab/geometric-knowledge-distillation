# %% [markdown]
# # Transformer Classifier with Skeleton Dataset

# %%
import os
import pickle
import torch
from torch.utils.data import Dataset, DataLoader
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.nn import functional as F
import matplotlib.pyplot as plt
import random
from tqdm import tqdm
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_fscore_support
import seaborn as sns
import numpy as np
import time

# %% [markdown]
# ## Dataloader from numpy files

# %%
class SkeletonDataset(Dataset):
    def __init__(self, data_path, split):
        self.X = np.load(os.path.join(data_path, f'X_{split}.npy'),  allow_pickle=True)
        self.y = np.load(os.path.join(data_path, f'y_{split}.npy'),  allow_pickle=True)
        self.X = self.X.reshape(self.X.shape[0], self.X.shape[2], self.X.shape[1])
        self.y = np.where(self.y == 27, 0, self.y)
    
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, idx):
        
        return torch.tensor(self.X[idx], dtype=torch.float32), torch.tensor(self.y[idx], dtype=torch.long)

def get_dataloader(data_path, split, batch_size):
    dataset = SkeletonDataset(data_path, split)
    return DataLoader(dataset, batch_size=batch_size, shuffle=False)

# Create train, validation, and test loaders
def get_all_dataloaders(data_path, batch_size):
    train_loader = get_dataloader(data_path, 'train', batch_size)
    test_loader = get_dataloader(data_path, 'test', batch_size)
    return train_loader, test_loader

# %%
train_loader, test_loader = get_all_dataloaders('Skeleton_numpy', batch_size=16)

# %%
for data, labels in train_loader:
    print("Data shape:", data.shape)
    print("Labels shape:", labels.shape)
    break
# Out:
# Data shape: torch.Size([16, 125, 60])
# Labels shape: torch.Size([16])

# %%
class TransformerClassifier(nn.Module):
    def __init__(self, input_dim, num_classes, num_heads=8, num_layers=4, hidden_dim=256, dropout=0.1):
        super(TransformerClassifier, self).__init__()
        
        self.input_dim = input_dim
        self.num_classes = num_classes
        
        # Transformer encoder layer
        encoder_layers = nn.TransformerEncoderLayer(
            d_model=input_dim,  # Input dimension (features per frame)
            nhead=num_heads,    # Number of attention heads
            dim_feedforward=hidden_dim,  # Feedforward hidden layer size
            dropout=dropout
        )
        
        # Stacked transformer encoder
        self.transformer_encoder = nn.TransformerEncoder(
            encoder_layers, num_layers=num_layers
        )
        
        # Classifier head
        self.fc = nn.Linear(input_dim, num_classes)  # Final layer to output class probabilities
    
    def forward(self, x):
        """
        x: (batch_size, time_steps, features)
        """
        # Transformer expects input of shape (sequence_length, batch_size, input_dim)
        x = x.permute(1, 0, 2)  # Shape: (time_steps, batch_size, features)
        
        # Apply transformer encoder
        transformer_out = self.transformer_encoder(x)
        
        # We take the output of the last time step (or average pooling across time)
        # For simplicity, let's use the last time step output (as a representation of the sequence)
        x = transformer_out[-1, :, :]  # Shape: (batch_size, features)
        
        # Classifier head to predict the class
        x = self.fc(x)
        return x

# %% [markdown]
# ## Modified transformer architecture for better performance on this dataset

# %%
class EnhancedTransformerClassifier(nn.Module):
    def __init__(self, input_dim, num_classes, num_heads=8, num_layers=6, hidden_dim=512, dropout=0.2):
        super(EnhancedTransformerClassifier, self).__init__()
        
        self.input_dim = input_dim
        self.num_classes = num_classes
        
        # Transformer encoder layer with more depth, hidden layers, and dropout
        encoder_layers = nn.TransformerEncoderLayer(
            d_model=input_dim,  # Input dimension (features per frame)
            nhead=num_heads,    # Number of attention heads
            dim_feedforward=hidden_dim,  # Feedforward hidden layer size
            dropout=dropout
        )
        
        # Stacked transformer encoder with more layers (increased depth)
        self.transformer_encoder = nn.TransformerEncoder(
            encoder_layers, num_layers=num_layers
        )
        
        # Use global average pooling instead of just the last time step output
        self.pooling = nn.AdaptiveAvgPool1d(1)  # Global average pooling across the time dimension
        
        # Classifier head
        self.fc = nn.Linear(input_dim, num_classes)  # Final layer to output class probabilities
        
        # Dropout for regularization
        self.dropout = nn.Dropout(dropout)
        
        # Layer Normalization for better training
        self.layer_norm = nn.LayerNorm(input_dim)

    def forward(self, x):
        """
        x: (batch_size, time_steps, features)
        """
        # Transformer expects input of shape (sequence_length, batch_size, input_dim)
        x = x.permute(1, 0, 2)  # Shape: (time_steps, batch_size, features)
        
        # Apply transformer encoder
        transformer_out = self.transformer_encoder(x)
        
        # Global average pooling (across time_steps)
        x = transformer_out.mean(dim=0)  # Shape: (batch_size, features)
        
        # Alternatively, we could also try adaptive pooling
        # x = self.pooling(transformer_out.permute(1, 2, 0)).squeeze(-1)  # Apply global average pooling
        
        # Layer normalization for better stability
        x = self.layer_norm(x)
        
        # Dropout to regularize the output
        x = self.dropout(x)
        
        # Classifier head to predict the class
        x = self.fc(x)
        return x

# %% [markdown]
# ## Training model

# %%
def train_model(model, train_loader, device, epochs=10, lr=1e-4):
    criterion = nn.CrossEntropyLoss()  # For classification task
    optimizer = optim.Adam(model.parameters(), lr=lr)
    
    model.to(device)  # Move model to CUDA if available

    for epoch in range(epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        
        for X_batch, y_batch in train_loader:
            X_batch, y_batch = X_batch.to(device), y_batch.to(device)  # Move data to device
            
            optimizer.zero_grad()
            
            # Forward pass
            outputs = model(X_batch)
            
            # Compute loss
            loss = criterion(outputs, y_batch)
            running_loss += loss.item()
            
            # Backward pass and optimize
            loss.backward()
            optimizer.step()
            
            # Calculate accuracy
            _, predicted = torch.max(outputs, 1)
            total += y_batch.size(0)
            correct += (predicted == y_batch).sum().item()

        epoch_loss = running_loss / len(train_loader)
        epoch_acc = 100 * correct / total
        print(f"Epoch {epoch+1}/{epochs}, Loss: {epoch_loss:.4f}, Accuracy: {epoch_acc:.2f}%")

# %%
input_dim = 60  # Number of features (e.g., 75 landmarks × 3 coordinates)
num_classes = 27 #len(set([item['y'] for item in train_loader.dataset]))  # Number of unique glosses
num_heads = 12
print(num_classes)

# Initialize model
model = EnhancedTransformerClassifier(input_dim=input_dim, num_heads = num_heads, num_classes=num_classes)
print(model)

# Select device (GPU if available, otherwise CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#device = torch.device("cpu")
# Train the model
train_model(model, train_loader, device=device, epochs=2000, lr=1e-4)

# Test the model on test data
model.eval()
correct = 0
total = 0
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)  # Move data to device
        outputs = model(X_batch)
        _, predicted = torch.max(outputs, 1)
        total += y_batch.size(0)
        correct += (predicted == y_batch).sum().item()

print(f"Test Accuracy: {100 * correct / total:.2f}%")
# Out:
# /anaconda/envs/azureml_py38/lib/python3.10/site-packages/torch/nn/modules/transformer.py:307: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")
# Epoch 1/2000, Loss: 3.4006, Accuracy: 3.71%
# Epoch 2/2000, Loss: 3.3383, Accuracy: 3.71%
# Epoch 3/2000, Loss: 3.3389, Accuracy: 4.45%
# Epoch 4/2000, Loss: 3.3095, Accuracy: 5.01%
# Epoch 5/2000, Loss: 3.3144, Accuracy: 3.15%
# Epoch 6/2000, Loss: 3.3312, Accuracy: 5.19%
# Epoch 7/2000, Loss: 3.3168, Accuracy: 5.19%
# Epoch 8/2000, Loss: 3.2876, Accuracy: 6.12%
# Epoch 9/2000, Loss: 3.2210, Accuracy: 5.75%
# Epoch 10/2000, Loss: 3.1259, Accuracy: 8.53%
# Epoch 377/2000, Loss: 0.0114, Accuracy: 99.81%
# Epoch 378/2000, Loss: 0.0125, Accuracy: 99.81%
# Epoch 379/2000, Loss: 0.0211, Accuracy: 99.44%
# Epoch 380/2000, Loss: 0.0242, Accuracy: 99.63%
# Epoch 381/2000, Loss: 0.0364, Accuracy: 99.07%
# Epoch 382/2000, Loss: 0.0272, Accuracy: 99.07%
# Epoch 383/2000, Loss: 0.0500, Accuracy: 98.14%
# Epoch 384/2000, Loss: 0.0204, Accuracy: 99.44%
# Epoch 385/2000, Loss: 0.0193, Accuracy: 99.44%
# Epoch 386/2000, Loss: 0.0138, Accuracy: 99.81%
# Epoch 387/2000, Loss: 0.0187, Accuracy: 99.44%
# Epoch 388/2000, Loss: 0.0368, Accuracy: 98.89%
# Epoch 389/2000, Loss: 0.0325, Accuracy: 99.26%
# Epoch 390/2000, Loss: 0.0114, Accuracy: 99.81%
# Epoch 391/2000, Loss: 0.0071, Accuracy: 100.00%
# Epoch 392/2000, Loss: 0.0064, Accuracy: 100.00%
# Epoch 393/2000, Loss: 0.0084, Accuracy: 100.00%
# Epoch 394/2000, Loss: 0.0066, Accuracy: 100.00%
# Epoch 395/2000, Loss: 0.0159, Accuracy: 99.63%
# Epoch 396/2000, Loss: 0.0340, Accuracy: 99.26%
# Epoch 397/2000, Loss: 0.0105, Accuracy: 100.00%
# Epoch 398/2000, Loss: 0.0153, Accuracy: 99.81%
# Epoch 399/2000, Loss: 0.0249, Accuracy: 99.44%
# Epoch 400/2000, Loss: 0.0191, Accuracy: 99.81%
# Epoch 401/2000, Loss: 0.0179, Accuracy: 99.81%
# Epoch 402/2000, Loss: 0.0203, Accuracy: 99.26%
# Epoch 403/2000, Loss: 0.0208, Accuracy: 99.81%
# Epoch 404/2000, Loss: 0.0275, Accuracy: 99.44%
# Epoch 405/2000, Loss: 0.0118, Accuracy: 99.81%
# Epoch 406/2000, Loss: 0.0338, Accuracy: 98.70%
# Epoch 407/2000, Loss: 0.0163, Accuracy: 99.81%
# Epoch 408/2000, Loss: 0.0156, Accuracy: 99.63%
# Epoch 409/2000, Loss: 0.0137, Accuracy: 99.81%
# Epoch 410/2000, Loss: 0.0101, Accuracy: 99.81%
# Epoch 411/2000, Loss: 0.0069, Accuracy: 100.00%
# Epoch 412/2000, Loss: 0.0052, Accuracy: 100.00%
# Epoch 413/2000, Loss: 0.0126, Accuracy: 99.63%
# Epoch 414/2000, Loss: 0.0136, Accuracy: 99.63%
# Epoch 415/2000, Loss: 0.0181, Accuracy: 99.63%
# Epoch 416/2000, Loss: 0.0075, Accuracy: 100.00%
# Epoch 417/2000, Loss: 0.0222, Accuracy: 99.63%
# Epoch 418/2000, Loss: 0.0398, Accuracy: 98.70%
# Epoch 419/2000, Loss: 0.0141, Accuracy: 99.63%
# Epoch 420/2000, Loss: 0.0268, Accuracy: 99.44%
# Epoch 421/2000, Loss: 0.0130, Accuracy: 99.81%
# Epoch 422/2000, Loss: 0.0089, Accuracy: 99.81%
# Epoch 469/2000, Loss: 0.0152, Accuracy: 99.44%
# Epoch 470/2000, Loss: 0.0152, Accuracy: 99.63%
# Epoch 471/2000, Loss: 0.0080, Accuracy: 100.00%
# Epoch 472/2000, Loss: 0.0077, Accuracy: 99.81%
# Epoch 473/2000, Loss: 0.0106, Accuracy: 99.81%
# Epoch 474/2000, Loss: 0.0097, Accuracy: 99.63%
# Epoch 475/2000, Loss: 0.0089, Accuracy: 99.81%
# Epoch 476/2000, Loss: 0.0054, Accuracy: 100.00%
# Epoch 477/2000, Loss: 0.0034, Accuracy: 100.00%
# Epoch 478/2000, Loss: 0.0034, Accuracy: 100.00%
# Epoch 479/2000, Loss: 0.0034, Accuracy: 100.00%
# Epoch 480/2000, Loss: 0.0034, Accuracy: 100.00%
# Epoch 481/2000, Loss: 0.0034, Accuracy: 100.00%
# Epoch 482/2000, Loss: 0.0117, Accuracy: 99.44%
# Epoch 483/2000, Loss: 0.0503, Accuracy: 98.89%
# Epoch 484/2000, Loss: 0.0264, Accuracy: 98.89%
# Epoch 485/2000, Loss: 0.0081, Accuracy: 99.81%
# Epoch 486/2000, Loss: 0.0219, Accuracy: 99.63%
# Epoch 487/2000, Loss: 0.0189, Accuracy: 99.63%
# Epoch 488/2000, Loss: 0.0118, Accuracy: 99.81%
# Epoch 489/2000, Loss: 0.0051, Accuracy: 99.81%
# Epoch 490/2000, Loss: 0.0037, Accuracy: 100.00%
# Epoch 491/2000, Loss: 0.0045, Accuracy: 100.00%
# Epoch 492/2000, Loss: 0.0026, Accuracy: 100.00%
# Epoch 493/2000, Loss: 0.0027, Accuracy: 100.00%
# Epoch 494/2000, Loss: 0.0024, Accuracy: 100.00%
# Epoch 495/2000, Loss: 0.0032, Accuracy: 100.00%
# Epoch 496/2000, Loss: 0.0158, Accuracy: 99.81%
# Epoch 497/2000, Loss: 0.0071, Accuracy: 99.81%
# Epoch 498/2000, Loss: 0.0094, Accuracy: 99.81%
# Epoch 499/2000, Loss: 0.0080, Accuracy: 100.00%
# Epoch 500/2000, Loss: 0.0089, Accuracy: 99.81%
# Epoch 501/2000, Loss: 0.0156, Accuracy: 99.44%
# Epoch 502/2000, Loss: 0.0064, Accuracy: 100.00%
# Epoch 503/2000, Loss: 0.0232, Accuracy: 99.26%
# Epoch 504/2000, Loss: 0.0364, Accuracy: 98.33%
# Epoch 505/2000, Loss: 0.0282, Accuracy: 99.81%
# Epoch 506/2000, Loss: 0.0227, Accuracy: 99.07%
# Epoch 507/2000, Loss: 0.0133, Accuracy: 99.81%
# Epoch 508/2000, Loss: 0.0082, Accuracy: 100.00%
# Epoch 509/2000, Loss: 0.0050, Accuracy: 100.00%
# Epoch 510/2000, Loss: 0.0135, Accuracy: 99.81%
# Epoch 511/2000, Loss: 0.0170, Accuracy: 99.63%
# Epoch 512/2000, Loss: 0.0270, Accuracy: 99.26%
# Epoch 513/2000, Loss: 0.0213, Accuracy: 99.63%
# Epoch 514/2000, Loss: 0.0705, Accuracy: 97.77%
# Epoch 515/2000, Loss: 0.0865, Accuracy: 96.85%
# Epoch 516/2000, Loss: 0.0708, Accuracy: 98.14%
# Epoch 517/2000, Loss: 0.0191, Accuracy: 99.63%
# Epoch 518/2000, Loss: 0.0179, Accuracy: 99.44%
# Epoch 519/2000, Loss: 0.0149, Accuracy: 99.63%
# Epoch 520/2000, Loss: 0.0298, Accuracy: 98.89%
# Epoch 521/2000, Loss: 0.0169, Accuracy: 99.44%
# Epoch 522/2000, Loss: 0.0067, Accuracy: 100.00%
# Epoch 523/2000, Loss: 0.0031, Accuracy: 100.00%
# Epoch 524/2000, Loss: 0.0042, Accuracy: 100.00%
# Epoch 525/2000, Loss: 0.0033, Accuracy: 100.00%
# Epoch 526/2000, Loss: 0.0132, Accuracy: 99.44%
# Epoch 527/2000, Loss: 0.0392, Accuracy: 98.70%
# Epoch 528/2000, Loss: 0.0459, Accuracy: 99.07%
# Epoch 529/2000, Loss: 0.0548, Accuracy: 98.33%
# Epoch 530/2000, Loss: 0.0558, Accuracy: 97.96%
# Epoch 531/2000, Loss: 0.0876, Accuracy: 97.22%
# Epoch 532/2000, Loss: 0.0781, Accuracy: 97.77%
# Epoch 533/2000, Loss: 0.0908, Accuracy: 97.77%
# Epoch 534/2000, Loss: 0.0407, Accuracy: 98.70%
# Epoch 535/2000, Loss: 0.0262, Accuracy: 99.26%
# Epoch 536/2000, Loss: 0.0224, Accuracy: 99.26%
# Epoch 537/2000, Loss: 0.0144, Accuracy: 99.81%
# Epoch 538/2000, Loss: 0.0050, Accuracy: 100.00%
# Epoch 539/2000, Loss: 0.0044, Accuracy: 100.00%
# Epoch 540/2000, Loss: 0.0037, Accuracy: 100.00%
# Epoch 541/2000, Loss: 0.0038, Accuracy: 100.00%
# Epoch 542/2000, Loss: 0.0021, Accuracy: 100.00%
# Epoch 543/2000, Loss: 0.0028, Accuracy: 100.00%
# Epoch 544/2000, Loss: 0.0062, Accuracy: 99.81%
# Epoch 545/2000, Loss: 0.0049, Accuracy: 100.00%
# Epoch 546/2000, Loss: 0.0048, Accuracy: 99.81%
# Epoch 547/2000, Loss: 0.0521, Accuracy: 98.89%
# Epoch 548/2000, Loss: 0.0309, Accuracy: 99.07%
# Epoch 549/2000, Loss: 0.0053, Accuracy: 100.00%
# Epoch 550/2000, Loss: 0.0053, Accuracy: 100.00%
# Epoch 551/2000, Loss: 0.0032, Accuracy: 100.00%
# Epoch 552/2000, Loss: 0.0021, Accuracy: 100.00%
# Epoch 553/2000, Loss: 0.0018, Accuracy: 100.00%
# Epoch 554/2000, Loss: 0.0020, Accuracy: 100.00%
# Epoch 555/2000, Loss: 0.0025, Accuracy: 100.00%
# Epoch 556/2000, Loss: 0.0038, Accuracy: 99.81%
# Epoch 557/2000, Loss: 0.0099, Accuracy: 99.63%
# Epoch 558/2000, Loss: 0.0124, Accuracy: 99.63%
# Epoch 559/2000, Loss: 0.0070, Accuracy: 99.81%
# Epoch 560/2000, Loss: 0.0045, Accuracy: 100.00%
# Epoch 561/2000, Loss: 0.0032, Accuracy: 100.00%
# Epoch 562/2000, Loss: 0.0018, Accuracy: 100.00%
# Epoch 563/2000, Loss: 0.0016, Accuracy: 100.00%
# Epoch 564/2000, Loss: 0.0014, Accuracy: 100.00%
# Epoch
2000, Loss: 0.0015, Accuracy: 100.00%
# Epoch 657/2000, Loss: 0.0024, Accuracy: 100.00%
# Epoch 658/2000, Loss: 0.0020, Accuracy: 100.00%
# Epoch 659/2000, Loss: 0.0021, Accuracy: 100.00%
# Epoch 660/2000, Loss: 0.0022, Accuracy: 100.00%
# Epoch 661/2000, Loss: 0.0074, Accuracy: 99.63%
# Epoch 662/2000, Loss: 0.0054, Accuracy: 99.81%
# Epoch 663/2000, Loss: 0.0021, Accuracy: 100.00%
# Epoch 664/2000, Loss: 0.0127, Accuracy: 99.63%
# Epoch 665/2000, Loss: 0.0175, Accuracy: 99.81%
# Epoch 666/2000, Loss: 0.0029, Accuracy: 100.00%
# Epoch 667/2000, Loss: 0.0023, Accuracy: 100.00%
# Epoch 668/2000, Loss: 0.0017, Accuracy: 100.00%
# Epoch 669/2000, Loss: 0.0016, Accuracy: 100.00%
# Epoch 670/2000, Loss: 0.0174, Accuracy: 99.26%
# Epoch 671/2000, Loss: 0.0093, Accuracy: 99.81%
# Epoch 672/2000, Loss: 0.0021, Accuracy: 100.00%
# Epoch 673/2000, Loss: 0.0015, Accuracy: 100.00%
# Epoch 674/2000, Loss: 0.0021, Accuracy: 100.00%
# Epoch 675/2000, Loss: 0.0016, Accuracy: 100.00%
# Epoch 676/2000, Loss: 0.0013, Accuracy: 100.00%
# Epoch 677/2000, Loss: 0.0015, Accuracy: 100.00%
# Epoch 678/2000, Loss: 0.0022, Accuracy: 100.00%
# Epoch 679/2000, Loss: 0.0190, Accuracy: 99.63%
# Epoch 680/2000, Loss: 0.0067, Accuracy: 100.00%
# Epoch 681/2000, Loss: 0.0042, Accuracy: 100.00%
# Epoch 682/2000, Loss: 0.0075, Accuracy: 99.81%
# Epoch 683/2000, Loss: 0.0043, Accuracy: 100.00%
# Epoch 684/2000, Loss: 0.0187, Accuracy: 99.44%
# Epoch 685/2000, Loss: 0.0293, Accuracy: 99.07%
# Epoch 686/2000, Loss: 0.0208, Accuracy: 99.44%
# Epoch 687/2000, Loss: 0.0283, Accuracy: 99.07%
# Epoch 688/2000, Loss: 0.0292, Accuracy: 99.26%
# Epoch 689/2000, Loss: 0.0203, Accuracy: 99.44%
# Epoch 690/2000, Loss: 0.0041, Accuracy: 100.00%
# Epoch 691/2000, Loss: 0.0049, Accuracy: 100.00%
# Epoch 692/2000, Loss: 0.0025, Accuracy: 100.00%
# Epoch 693/2000, Loss: 0.0192, Accuracy: 99.07%
# Epoch 694/2000, Loss: 0.0848, Accuracy: 97.40%
# Epoch 695/2000, Loss: 0.0284, Accuracy: 99.07%
# Epoch 696/2000, Loss: 0.0190, Accuracy: 99.44%
# Epoch 697/2000, Loss: 0.0109, Accuracy: 99.63%
# Epoch 698/2000, Loss: 0.0097, Accuracy: 99.63%
# Epoch 699/2000, Loss: 0.0116, Accuracy: 99.63%
# Epoch 700/2000, Loss: 0.0224, Accuracy: 99.63%
# Epoch 701/2000, Loss: 0.0043, Accuracy: 100.00%
# Epoch 702/2000, Loss: 0.0082, Accuracy: 99.63%
# Epoch 703/2000, Loss: 0.0130, Accuracy: 99.44%
# Epoch 704/2000, Loss: 0.0028, Accuracy: 100.00%
# Epoch 705/2000, Loss: 0.0027, Accuracy: 100.00%
# Epoch 706/2000, Loss: 0.0015, Accuracy: 100.00%
# Epoch 707/2000, Loss: 0.0012, Accuracy: 100.00%
# Epoch 708/2000, Loss: 0.0062, Accuracy: 99.63%
# Epoch 709/2000, Loss: 0.0062, Accuracy: 99.81%
# Epoch 710/2000, Loss: 0.0090, Accuracy: 99.63%
# Epoch 711/2000, Loss: 0.0511, Accuracy: 98.70%
# Epoch 712/2000, Loss: 0.0435, Accuracy: 98.89%
# Epoch 713/2000, Loss: 0.0611, Accuracy: 97.96%
# Epoch 714/2000, Loss: 0.0347, Accuracy: 98.52%
# Epoch 715/2000, Loss: 0.0115, Accuracy: 99.81%
# Epoch 716/2000, Loss: 0.0053, Accuracy: 100.00%
# Epoch 717/2000, Loss: 0.0023, Accuracy: 100.00%
# Epoch 718/2000, Loss: 0.0023, Accuracy: 100.00%
# Epoch 719/2000, Loss: 0.0011, Accuracy: 100.00%
# Epoch 720/2000, Loss: 0.0055, Accuracy: 99.81%
# Epoch 721/2000, Loss: 0.0079, Accuracy: 99.81%
# Epoch 722/2000, Loss: 0.0024, Accuracy: 100.00%
# Epoch 723/2000, Loss: 0.0022, Accuracy: 100.00%
# Epoch 724/2000, Loss: 0.0133, Accuracy: 99.63%
# Epoch 725/2000, Loss: 0.0036, Accuracy: 100.00%
# Epoch 726/2000, Loss: 0.0019, Accuracy: 100.00%
# Epoch 727/2000, Loss: 0.0029, Accuracy: 100.00%
# Epoch 728/2000, Loss: 0.0018, Accuracy: 100.00%
# Epoch 729/2000, Loss: 0.0034, Accuracy: 99.81%
# Epoch 730/2000, Loss: 0.0268, Accuracy: 99.07%
# Epoch 731/2000, Loss: 0.0343, Accuracy: 98.89%
# Epoch 732/2000, Loss: 0.0445, Accuracy: 98.70%
# Epoch 733/2000, Loss: 0.0191, Accuracy: 99.44%
# Epoch 734/2000, Loss: 0.0102, Accuracy: 99.81%
# Epoch 735/2000, Loss: 0.0049, Accuracy: 99.81%
# Epoch 736/2000, Loss: 0.0050, Accuracy: 99.63%
# Epoch 737/2000, Loss: 0.0497, Accuracy: 98.14%
# Epoch 738/2000, Loss: 0.0176, Accuracy: 99.63%
# Epoch 739/2000, Loss: 0.0038, Accuracy: 100.00%
# Epoch 740/2000, Loss: 0.0018, Accuracy: 100.00%
# Epoch 741/2000, Loss: 0.0025, Accuracy: 100.00%
# Epoch 742/2000, Loss: 0.0067, Accuracy: 99.81%
# Epoch 743/2000, Loss: 0.0124, Accuracy: 99.81%
# Epoch 744/2000, Loss: 0.0081, Accuracy: 99.81%
# Epoch 745/2000, Loss: 0.0018, Accuracy: 100.00%
# Epoch 746/2000, Loss: 0.0025, Accuracy: 100.00%
# Epoch 747/2000, Loss: 0.0021, Accuracy: 100.00%
# Epoch 748/2000, Loss: 0.0017, Accuracy: 100.00%
# Epoch 749/2000, Loss: 0.0038, Accuracy: 100.00%
# Epoch 750/2000, Loss: 0.0029, Accuracy: 100.00%
# Epoch 751/2000, Loss: 0.0263, Accuracy: 99.44%
# Epoch 752/2000, Loss: 0.0145, Accuracy: 99.26%
# Epoch 753/2000, Loss: 0.0381, Accuracy: 98.33%
# Epoch 754/2000, Loss: 0.0256, Accuracy: 99.63%
# Epoch 755/2000, Loss: 0.0221, Accuracy: 99.44%
# Epoch 756/2000, Loss: 0.0124, Accuracy: 99.63%
# Epoch 757/2000, Loss: 0.0049, Accuracy: 99.81%
# Epoch 758/2000, Loss: 0.0018, Accuracy: 100.00%
# Epoch 759/2000, Loss: 0.0019, Accuracy: 100.00%
# Epoch 760/2000, Loss: 0.0042, Accuracy: 100.00%
# Epoch 761/2000, Loss: 0.0117, Accuracy: 99.26%
# Epoch 762/2000, Loss: 0.0131, Accuracy: 99.63%
# Epoch 763/2000, Loss: 0.0047, Accuracy: 99.81%
# Epoch 764/2000, Loss: 0.0036, Accuracy: 100.00%
# Epoch 765/2000, Loss: 0.0072, Accuracy: 99.81%
# Epoch 766/2000, Loss: 0.0055, Accuracy: 100.00%
# Epoch 767/2000, Loss: 0.0238, Accuracy: 99.26%
# Epoch 768/2000, Loss: 0.0168, Accuracy: 99.63%
# Epoch 769/2000, Loss: 0.0056, Accuracy: 99.81%
# Epoch 770/2000, Loss: 0.0037, Accuracy: 100.00%
# Epoch 771/2000, Loss: 0.0020, Accuracy: 100.00%
# Epoch 772/2000, Loss: 0.0020, Accuracy: 100.00%
# Epoch 773/2000, Loss: 0.0010, Accuracy: 100.00%
# Epoch 774/2000, Loss: 0.0014, Accuracy: 100.00%
# Epoch 775/2000, Loss: 0.0016, Accuracy: 100.00%
# Epoch 776/2000, Loss: 0.0032, Accuracy: 99.81%
# Epoch 777/2000, Loss: 0.0029, Accuracy: 99.81%
# Epoch 778/2000, Loss: 0.0037, Accuracy: 100.00%
# Epoch 779/2000, Loss: 0.0013, Accuracy: 100.00%
# Epoch 780/2000, Loss: 0.0009, Accuracy: 100.00%
# Epoch 781/2000, Loss: 0.0010, Accuracy: 100.00%
# Epoch 782/2000, Loss: 0.0017, Accuracy: 100.00%
# Epoch 783/2000, Loss: 0.0009, Accuracy: 100.00%
# Epoch 784/2000, Loss: 0.0007, Accuracy: 100.00%
# Epoch 785/2000, Loss: 0.0164, Accuracy: 99.44%
# Epoch 786/2000, Loss: 0.0631, Accuracy: 97.96%
# Epoch 787/2000, Loss: 0.0591, Accuracy: 98.33%
# Epoch 788/2000, Loss: 0.0166, Accuracy: 99.26%
# Epoch 789/2000, Loss: 0.0222, Accuracy: 99.44%
# Epoch 790/2000, Loss: 0.0114, Accuracy: 99.44%
# Epoch 791/2000, Loss: 0.0141, Accuracy: 99.63%
# Epoch 792/2000, Loss: 0.0033, Accuracy: 100.00%
# Epoch 793/2000, Loss: 0.0027, Accuracy: 100.00%
# Epoch 794/2000, Loss: 0.0050, Accuracy: 99.81%
# Epoch 795/2000, Loss: 0.0172, Accuracy: 99.63%
# Epoch 796/2000, Loss: 0.0054, Accuracy: 99.81%
# Epoch 797/2000, Loss: 0.0021, Accuracy: 100.00%
# Epoch 798/2000, Loss: 0.0030, Accuracy: 100.00%
# Epoch 799/2000, Loss: 0.0010, Accuracy: 100.00%
# Epoch 800/2000, Loss: 0.0012, Accuracy: 100.00%
# Epoch 801/2000, Loss: 0.0013, Accuracy: 100.00%
# Epoch 802/2000, Loss: 0.0009, Accuracy: 100.00%
# Epoch 803/2000, Loss: 0.0010, Accuracy: 100.00%
# Epoch 804/2000, Loss: 0.0011, Accuracy: 100.00%
# Epoch 805/2000, Loss: 0.0009, Accuracy: 100.00%
# Epoch 806/2000, Loss: 0.0010, Accuracy: 100.00%
# Epoch 807/2000, Loss: 0.0011, Accuracy: 100.00%
# Epoch 808/2000, Loss: 0.0008, Accuracy: 100.00%
# Epoch 809/2000, Loss: 0.0008, Accuracy: 100.00%
# Epoch 810/2000, Loss: 0.0008, Accuracy: 100.00%
# Epoch 811/2000, Loss: 0.0008, Accuracy: 100.00%
# Epoch 812/2000, Loss: 0.0008, Accuracy: 100.00%
# Epoch 813/2000, Loss: 0.0007, Accuracy: 100.00%
# Epoch 814/2000, Loss: 0.0012, Accuracy: 100.00%
# Epoch 815/2000, Loss: 0.0008, Accuracy: 100.00%
# Epoch 816/2000, Loss: 0.0009, Accuracy: 100.00%
# Epoch 817/2000, Loss: 0.0015, Accuracy: 100.00%
# Epoch 818/2000, Loss: 0.0011, Accuracy: 100.00%
# Epoch 819/2000, Loss: 0.0010, Accuracy: 100.00%
# Epoch 820/2000, Loss: 0.0018, Accuracy: 100.00%
# Epoch 821/2000, Loss: 0.0012, Accuracy: 100.00%
# Epoch 822/2000, Loss: 0.0026, Accuracy: 100.00%
# Epoch 823/2000, Loss: 0.0353, Accuracy: 98.89%
# Epoch 824/2000, Loss: 0.0500, Accuracy: 98.70%
# Epoch 825/2000, Loss: 0.0439, Accuracy: 98.33%
# Epoch 826/2000, Loss: 0.0490, Accuracy: 98.70%
# Epoch 827/2000, Loss: 0.0369, Accuracy: 98.52%
# Epoch 828/2000, Loss: 0.0410, Accuracy: 98.70%
# Epoch 829/2000, Loss: 0.0788, Accuracy: 97.96%
# Epoch 830/2000, Loss: 0.0195, Accuracy: 99.07%
# Epoch 831/2000, Loss: 0.0135, Accuracy: 99.44%
# Epoch 832/2000, Loss: 0.0079, Accuracy: 99.81%
# Epoch 833/2000, Loss: 0.0168, Accuracy: 99.63%
# Epoch 834/2000, Loss: 0.0114, Accuracy: 99.63%
# Epoch 835/2000, Loss: 0.0104, Accuracy: 99.81%
# Epoch 836/2000, Loss: 0.0085, Accuracy: 99.81%
# Epoch 837/2000, Loss: 0.0030, Accuracy: 100.00%
# Epoch 838/2000, Loss: 0.0027, Accuracy: 100.00%
# Epoch 839/2000, Loss: 0.0035, Accuracy: 99.81%
# Epoch 840/2000, Loss: 0.0086, Accuracy: 99.44%
# Epoch 841/2000, Loss: 0.0041, Accuracy: 100.00%
# Epoch 842/2000, Loss: 0.0018, Accuracy: 100.00%
# Epoch
2000, Loss: 0.0016, Accuracy: 100.00%
# Epoch 933/2000, Loss: 0.0113, Accuracy: 99.44%
# Epoch 934/2000, Loss: 0.0204, Accuracy: 99.26%
# Epoch 935/2000, Loss: 0.0310, Accuracy: 98.89%
# Epoch 936/2000, Loss: 0.0231, Accuracy: 99.44%
# Epoch 937/2000, Loss: 0.0108, Accuracy: 99.63%
# Epoch 938/2000, Loss: 0.0238, Accuracy: 99.26%
# Epoch 939/2000, Loss: 0.0073, Accuracy: 99.81%
# Epoch 940/2000, Loss: 0.0064, Accuracy: 99.81%
# Epoch 941/2000, Loss: 0.0060, Accuracy: 99.81%
# Epoch 942/2000, Loss: 0.0122, Accuracy: 99.63%
# Epoch 943/2000, Loss: 0.0039, Accuracy: 99.81%
# Epoch 944/2000, Loss: 0.0039, Accuracy: 100.00%
# Epoch 945/2000, Loss: 0.0013, Accuracy: 100.00%
# Epoch 946/2000, Loss: 0.0025, Accuracy: 100.00%
# Epoch 947/2000, Loss: 0.0025, Accuracy: 100.00%
# Epoch 948/2000, Loss: 0.0017, Accuracy: 100.00%
# Epoch 949/2000, Loss: 0.0008, Accuracy: 100.00%
# Epoch 950/2000, Loss: 0.0006, Accuracy: 100.00%
# Epoch 951/2000, Loss: 0.0009, Accuracy: 100.00%
# Epoch 952/2000, Loss: 0.0008, Accuracy: 100.00%
# Epoch 953/2000, Loss: 0.0008, Accuracy: 100.00%
# Epoch 954/2000, Loss: 0.0006, Accuracy: 100.00%
# Epoch 955/2000, Loss: 0.0021, Accuracy: 100.00%
# Epoch 956/2000, Loss: 0.0007, Accuracy: 100.00%
# Epoch 957/2000, Loss: 0.0005, Accuracy: 100.00%
# Epoch 958/2000, Loss: 0.0046, Accuracy: 99.81%
# Epoch 959/2000, Loss: 0.0155, Accuracy: 99.81%
# Epoch 960/2000, Loss: 0.0012, Accuracy: 100.00%
# Epoch 961/2000, Loss: 0.0010, Accuracy: 100.00%
# Epoch 962/2000, Loss: 0.0010, Accuracy: 100.00%
# Epoch 963/2000, Loss: 0.0013, Accuracy: 100.00%
# Epoch 964/2000, Loss: 0.0013, Accuracy: 100.00%
# Epoch 965/2000, Loss: 0.0007, Accuracy: 100.00%
# Epoch 966/2000, Loss: 0.0008, Accuracy: 100.00%
# Epoch 967/2000, Loss: 0.0007, Accuracy: 100.00%
# Epoch 968/2000, Loss: 0.0004, Accuracy: 100.00%
# Epoch 969/2000, Loss: 0.0006, Accuracy: 100.00%
# Epoch 970/2000, Loss: 0.0005, Accuracy: 100.00%
# Epoch 971/2000, Loss: 0.0007, Accuracy: 100.00%
# Epoch 972/2000, Loss: 0.0006, Accuracy: 100.00%
# Epoch 973/2000, Loss: 0.0495, Accuracy: 98.89%
# Epoch 974/2000, Loss: 0.0064, Accuracy: 100.00%
# Epoch 975/2000, Loss: 0.0152, Accuracy: 99.81%
# Epoch 976/2000, Loss: 0.0235, Accuracy: 99.07%
# Epoch 977/2000, Loss: 0.0642, Accuracy: 98.33%
# Epoch 978/2000, Loss: 0.0482, Accuracy: 98.14%
# Epoch 979/2000, Loss: 0.0562, Accuracy: 98.89%
# Epoch 980/2000, Loss: 0.0236, Accuracy: 99.07%
# Epoch 981/2000, Loss: 0.0481, Accuracy: 99.44%
# Epoch 982/2000, Loss: 0.0128, Accuracy: 99.63%
# Epoch 983/2000, Loss: 0.0036, Accuracy: 100.00%
# Epoch 984/2000, Loss: 0.0030, Accuracy: 100.00%
# Epoch 985/2000, Loss: 0.0017, Accuracy: 100.00%
# Epoch 986/2000, Loss: 0.0021, Accuracy: 100.00%
# Epoch 987/2000, Loss: 0.0013, Accuracy: 100.00%
# Epoch 988/2000, Loss: 0.0012, Accuracy: 100.00%
# Epoch 989/2000, Loss: 0.0020, Accuracy: 100.00%
# Epoch 990/2000, Loss: 0.0041, Accuracy: 100.00%
# Epoch 991/2000, Loss: 0.0014, Accuracy: 100.00%
# Epoch 992/2000, Loss: 0.0008, Accuracy: 100.00%
# Epoch 993/2000, Loss: 0.0041, Accuracy: 99.81%
# Epoch 994/2000, Loss: 0.0073, Accuracy: 99.81%
# Epoch 995/2000, Loss: 0.0201, Accuracy: 99.44%
# Epoch 996/2000, Loss: 0.0470, Accuracy: 98.89%
# Epoch 997/2000, Loss: 0.1002, Accuracy: 97.77%
# Epoch 998/2000, Loss: 0.0457, Accuracy: 98.52%
# Epoch 999/2000, Loss: 0.0378, Accuracy: 99.07%
# Epoch 1000/2000, Loss: 0.0177, Accuracy: 99.63%
# Epoch 1001/2000, Loss: 0.0065, Accuracy: 99.81%
# Epoch 1002/2000, Loss: 0.0222, Accuracy: 99.44%
# Epoch 1003/2000, Loss: 0.0027, Accuracy: 100.00%
# Epoch 1004/2000, Loss: 0.0059, Accuracy: 99.81%
# Epoch 1005/2000, Loss: 0.0043, Accuracy: 99.81%
# Epoch 1006/2000, Loss: 0.0021, Accuracy: 100.00%
# Epoch 1007/2000, Loss: 0.0009, Accuracy: 100.00%
# ...
# Epoch 1674/2000, Loss: 0.0060, Accuracy: 99.81%
# Epoch 1675/2000, Loss: 0.0034, Accuracy: 100.00%
# Epoch 1676/2000, Loss: 0.0013, Accuracy: 100.00%
# Epoch 1677/2000, Loss: 0.0010, Accuracy: 100.00%
# Epoch 1678/2000, Loss: 0.0010, Accuracy: 100.00%
# Epoch
2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1937/2000, Loss: 0.0004, Accuracy: 100.00%
# Epoch 1938/2000, Loss: 0.0004, Accuracy: 100.00%
# Epoch 1939/2000, Loss: 0.0007, Accuracy: 100.00%
# Epoch 1940/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1941/2000, Loss: 0.0010, Accuracy: 100.00%
# Epoch 1942/2000, Loss: 0.0008, Accuracy: 100.00%
# Epoch 1943/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1944/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1945/2000, Loss: 0.0006, Accuracy: 100.00%
# Epoch 1946/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1947/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1948/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1949/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1950/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1951/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1952/2000, Loss: 0.0002, Accuracy: 100.00%
# Epoch 1953/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1954/2000, Loss: 0.0004, Accuracy: 100.00%
# Epoch 1955/2000, Loss: 0.0006, Accuracy: 100.00%
# Epoch 1956/2000, Loss: 0.0004, Accuracy: 100.00%
# Epoch 1957/2000, Loss: 0.0002, Accuracy: 100.00%
# Epoch 1958/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1959/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1960/2000, Loss: 0.0002, Accuracy: 100.00%
# Epoch 1961/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1962/2000, Loss: 0.0002, Accuracy: 100.00%
# Epoch 1963/2000, Loss: 0.0006, Accuracy: 100.00%
# Epoch 1964/2000, Loss: 0.0007, Accuracy: 100.00%
# Epoch 1965/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1966/2000, Loss: 0.0002, Accuracy: 100.00%
# Epoch 1967/2000, Loss: 0.0130, Accuracy: 99.44%
# Epoch 1968/2000, Loss: 0.0131, Accuracy: 99.44%
# Epoch 1969/2000, Loss: 0.0024, Accuracy: 99.81%
# Epoch 1970/2000, Loss: 0.0012, Accuracy: 100.00%
# Epoch 1971/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1972/2000, Loss: 0.0166, Accuracy: 99.44%
# Epoch 1973/2000, Loss: 0.0417, Accuracy: 99.44%
# Epoch 1974/2000, Loss: 0.0017, Accuracy: 100.00%
# Epoch 1975/2000, Loss: 0.0014, Accuracy: 100.00%
# Epoch 1976/2000, Loss: 0.0007, Accuracy: 100.00%
# Epoch 1977/2000, Loss: 0.0004, Accuracy: 100.00%
# Epoch 1978/2000, Loss: 0.0004, Accuracy: 100.00%
# Epoch 1979/2000, Loss: 0.0004, Accuracy: 100.00%
# Epoch 1980/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1981/2000, Loss: 0.0036, Accuracy: 99.81%
# Epoch 1982/2000, Loss: 0.0154, Accuracy: 99.44%
# Epoch 1983/2000, Loss: 0.0207, Accuracy: 99.63%
# Epoch 1984/2000, Loss: 0.0018, Accuracy: 100.00%
# Epoch 1985/2000, Loss: 0.0010, Accuracy: 100.00%
# Epoch 1986/2000, Loss: 0.0009, Accuracy: 100.00%
# Epoch 1987/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1988/2000, Loss: 0.0002, Accuracy: 100.00%
# Epoch 1989/2000, Loss: 0.0002, Accuracy: 100.00%
# Epoch 1990/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1991/2000, Loss: 0.0011, Accuracy: 100.00%
# Epoch 1992/2000, Loss: 0.0004, Accuracy: 100.00%
# Epoch 1993/2000, Loss: 0.0004, Accuracy: 100.00%
# Epoch 1994/2000, Loss: 0.0004, Accuracy: 100.00%
# Epoch 1995/2000, Loss: 0.0002, Accuracy: 100.00%
# Epoch 1996/2000, Loss: 0.0004, Accuracy: 100.00%
# Epoch 1997/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 1998/2000, Loss: 0.0002, Accuracy: 100.00%
# Epoch 1999/2000, Loss: 0.0003, Accuracy: 100.00%
# Epoch 2000/2000, Loss: 0.0002, Accuracy: 100.00%
# Test Accuracy: 57.45%

# %% [markdown]
# ## Test results

# %%
model.eval()
correct = 0
total = 0
start=time.time()
with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)  # Move data to device
        outputs = model(X_batch)
        _, predicted = torch.max(outputs, 1)
        total += y_batch.size(0)
        correct += (predicted == y_batch).sum().item()
end = time.time()
print(f"Test Accuracy: {100 * correct / total:.2f}%")
print("Time per sample:", (end-start)*1000/total)
# Out:
# Test Accuracy: 57.45%
# Time per sample: 0.2052635879990477

# %% [markdown]
# ## Print metrics

# %%
from sklearn.metrics import precision_recall_fscore_support, accuracy_score

model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for X_batch, y_batch in test_loader:
        X_batch, y_batch = X_batch.to(device), y_batch.to(device)  # Move data to device
        outputs = model(X_batch)
        _, predicted = torch.max(outputs, 1)

        all_preds.extend(predicted.cpu().numpy())  # Collect predictions
        all_labels.extend(y_batch.cpu().numpy())  # Collect true labels

# Calculate precision, recall, F1 score (macro averaged), and accuracy
precision, recall, f1, _ = precision_recall_fscore_support(all_labels, all_preds, average='macro')
accuracy = accuracy_score(all_labels, all_preds)

print(f"Test Accuracy: {accuracy * 100}%")
print(f"Test Precision (Macro): {precision}")
print(f"Test Recall (Macro): {recall}")
print(f"Test F1 Score (Macro): {f1}")
# Out:
# Test Accuracy: 57.453416149068325%
# Test Precision (Macro): 0.6085554877221543
# Test Recall (Macro): 0.5754769921436589
# Test F1 Score (Macro): 0.555776354190826
